# %%
def func01():
    print("这是func01开始")
    num=1/0
    print("这是func01结束")

def func02():
    print("这是FUNC02开始")
    func01()
    print("这是FUNC02结束")

def main():
    try:
        func02()
    except Exception as e:
        print(e)
main()
# Out:
# 这是FUNC02开始
# 这是func01开始
# division by zero
